# %% [markdown]
# ### **Task 1: Exploratory Data Analysis (EDA)**

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/mushroom.csv")

# %%
df
# Out:
#       Unnamed: 0 cap_shape cap_surface cap_color bruises     odor  \
# 0           1167    sunken       scaly     white      no    anise
# 1           1037    sunken     fibrous       red      no    anise
# 2            309      flat     grooves    purple     yes     foul
# 3            282      bell       scaly      pink     yes    fishy
# 4            820      flat      smooth    yellow     yes    musty
# ...          ...       ...         ...       ...     ...      ...
# 1995         863    sunken       scaly     brown     yes     foul
# 1996        1160    sunken       scaly    purple     yes    musty
# 1997         265    convex     grooves     green     yes    fishy
# 1998         411      bell      smooth     white      no  pungent
# 1999        1073    convex       scaly    yellow     yes  pungent
#
#      gill_attachment gill_spacing gill_size gill_color  ...  veil_type  \
# 0         descending      distant     broad       pink  ...    partial
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  stalk_height  cap_diameter
# count  2000.000000   2000.000000   2000.000000
# mean    624.974000      8.449118     12.314345
# std     375.091938      3.697217      7.048845
# min       0.000000      2.000000      1.000000
# 25%     290.000000      5.291009      5.723521
# 50%     607.000000      8.318596     12.124902
# 75%     957.250000     11.781272     18.698606
# max    1279.000000     15.095066     25.000054

# %%
df.describe(include=object)
# Out:
#        cap_shape cap_surface cap_color bruises  odor gill_attachment  \
# count       2000        2000      2000    2000  2000            2000
# unique         5           4         9       2     9               4
# top       sunken       scaly     brown     yes  foul            free
# freq         439         568       263    1023   274             540
#
#        gill_spacing gill_size gill_color stalk_shape  ...  \
# count          2000      2000       2000        2000  ...
# unique            3         2         12           2  ...
# top         distant    narrow     orange   enlarging  ...
# freq            677      1007        216        1040  ...
#
#        stalk_color_above_ring stalk_color_below_ring  veil_type veil_color  \
# count                    2000                   2000       2000       2000
# unique                      9                      9          2          4
# top                     brown                 orange  universal      white
# ...

# %%
#data types
df.dtypes
# Out:
# Unnamed: 0                    int64
# cap_shape                    object
# cap_surface                  object
# cap_color                    object
# bruises                      object
# odor                         object
# gill_attachment              object
# gill_spacing                 object
# gill_size                    object
# gill_color                   object
# stalk_shape                  object
# stalk_root                   object
# stalk_surface_above_ring     object
# stalk_surface_below_ring     object
# stalk_color_above_ring       object
# stalk_color_below_ring       object
# veil_type                    object
# veil_color                   object
# ring_number                  object
# ring_type                    object
# spore_print_color            object
# population                   object
# habitat                      object
# class                        object
# stalk_height                float64
# cap_diameter                float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2000 non-null   int64
#  1   cap_shape                 2000 non-null   object
#  2   cap_surface               2000 non-null   object
#  3   cap_color                 2000 non-null   object
#  4   bruises                   2000 non-null   object
#  5   odor                      2000 non-null   object
#  6   gill_attachment           2000 non-null   object
#  7   gill_spacing              2000 non-null   object
#  8   gill_size                 2000 non-null   object
#  9   gill_color                2000 non-null   object
#  10  stalk_shape               2000 non-null   object
#  11  stalk_root                2000 non-null   object
#  12  stalk_surface_above_ring  2000 non-null   object
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995     True
# 1996    False
# 1997     True
# 1998     True
# 1999    False
# Length: 2000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1024

# %%
df[df.duplicated()]
# Out:
#       Unnamed: 0 cap_shape cap_surface cap_color bruises     odor  \
# 34          1279      bell      smooth      pink      no     foul
# 70          1275    sunken       scaly    yellow      no  pungent
# 76           549   conical     grooves     brown      no     foul
# 109         1198    sunken      smooth     white      no    anise
# 127         1167    sunken       scaly     white      no    anise
# ...          ...       ...         ...       ...     ...      ...
# 1993         618      flat     grooves     green     yes    musty
# 1994         871      flat       scaly      pink      no    spicy
# 1995         863    sunken       scaly     brown     yes     foul
# 1997         265    convex     grooves     green     yes    fishy
# 1998         411      bell      smooth     white      no  pungent
#
#      gill_attachment gill_spacing gill_size gill_color  ...  veil_type  \
# 34           notched      distant     broad       pink  ...  universal
# ...

# %%
df[df.duplicated(keep = False)]
# Out:
#       Unnamed: 0 cap_shape cap_surface cap_color bruises     odor  \
# 0           1167    sunken       scaly     white      no    anise
# 1           1037    sunken     fibrous       red      no    anise
# 2            309      flat     grooves    purple     yes     foul
# 3            282      bell       scaly      pink     yes    fishy
# 4            820      flat      smooth    yellow     yes    musty
# ...          ...       ...         ...       ...     ...      ...
# 1993         618      flat     grooves     green     yes    musty
# 1994         871      flat       scaly      pink      no    spicy
# 1995         863    sunken       scaly     brown     yes     foul
# 1997         265    convex     grooves     green     yes    fishy
# 1998         411      bell      smooth     white      no  pungent
#
#      gill_attachment gill_spacing gill_size gill_color  ...  veil_type  \
# 0         descending      distant     broad       pink  ...    partial
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (976, 26)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Unnamed: 0 cap_shape cap_surface cap_color bruises   odor gill_attachment  \
# 0        1167    sunken       scaly     white      no  anise      descending
# 1        1037    sunken     fibrous       red      no  anise         notched
# 2         309      flat     grooves    purple     yes   foul      descending
# 3         282      bell       scaly      pink     yes  fishy         notched
# 4         820      flat      smooth    yellow     yes  musty            free
#
#   gill_spacing gill_size gill_color  ...  veil_type veil_color ring_number  \
# 0      distant     broad       pink  ...    partial      brown         two
# 1      crowded    narrow  chocolate  ...  universal      brown         two
# 2      crowded     broad     purple  ...  universal     yellow         two
# 3        close     broad     orange  ...    partial     yellow         two
# 4      crowded    narrow     orange  ...  universal      white        none
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'cap_shape', 'cap_surface', 'cap_color', 'bruises',
#        'odor', 'gill_attachment', 'gill_spacing', 'gill_size', 'gill_color',
#        'stalk_shape', 'stalk_root', 'stalk_surface_above_ring',
#        'stalk_surface_below_ring', 'stalk_color_above_ring',
#        'stalk_color_below_ring', 'veil_type', 'veil_color', 'ring_number',
#        'ring_type', 'spore_print_color', 'population', 'habitat', 'class',
#        'stalk_height', 'cap_diameter'],
#       dtype='object')

# %%
df.isna()
# Out:
#       Unnamed: 0  cap_shape  cap_surface  cap_color  bruises   odor  \
# 0          False      False        False      False    False  False
# 1          False      False        False      False    False  False
# 2          False      False        False      False    False  False
# 3          False      False        False      False    False  False
# 4          False      False        False      False    False  False
# ...          ...        ...          ...        ...      ...    ...
# 1985       False      False        False      False    False  False
# 1988       False      False        False      False    False  False
# 1989       False      False        False      False    False  False
# 1996       False      False        False      False    False  False
# 1999       False      False        False      False    False  False
#
#       gill_attachment  gill_spacing  gill_size  gill_color  ...  veil_type  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                  0
# cap_shape                   0
# cap_surface                 0
# cap_color                   0
# bruises                     0
# odor                        0
# gill_attachment             0
# gill_spacing                0
# gill_size                   0
# gill_color                  0
# stalk_shape                 0
# stalk_root                  0
# stalk_surface_above_ring    0
# stalk_surface_below_ring    0
# stalk_color_above_ring      0
# stalk_color_below_ring      0
# veil_type                   0
# veil_color                  0
# ring_number                 0
# ring_type                   0
# spore_print_color           0
# population                  0
# habitat                     0
# class                       0
# stalk_height                0
# cap_diameter                0
# dtype: int64

# %% [markdown]
# ### **Task 3: Data Visualization**

# %%
import matplotlib.pyplot as plt
df.hist()
plt.tight_layout()

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# ### **Task 2: Data Preprocessing**

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
data =pd.read_csv("mushroom.csv",index_col=0)

# %%
data1=df.copy()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'cap_shape', 'cap_surface', 'cap_color', 'bruises',
#        'odor', 'gill_attachment', 'gill_spacing', 'gill_size', 'gill_color',
#        'stalk_shape', 'stalk_root', 'stalk_surface_above_ring',
#        'stalk_surface_below_ring', 'stalk_color_above_ring',
#        'stalk_color_below_ring', 'veil_type', 'veil_color', 'ring_number',
#        'ring_type', 'spore_print_color', 'population', 'habitat', 'class',
#        'stalk_height', 'cap_diameter'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    Unnamed: 0 cap_shape cap_surface cap_color bruises   odor gill_attachment  \
# 0        1167    sunken       scaly     white      no  anise      descending
# 1        1037    sunken     fibrous       red      no  anise         notched
# 2         309      flat     grooves    purple     yes   foul      descending
#
#   gill_spacing gill_size gill_color  ...  veil_type veil_color ring_number  \
# 0      distant     broad       pink  ...    partial      brown         two
# 1      crowded    narrow  chocolate  ...  universal      brown         two
# 2      crowded     broad     purple  ...  universal     yellow         two
#
#    ring_type spore_print_color population habitat      class stalk_height  \
# 0  sheathing         chocolate  clustered   waste  poisonous    14.276173
# 1  sheathing             brown   numerous   waste     edible     3.952715
# 2  sheathing            purple   abundant   waste  poisonous     9.054265
#
#   cap_diameter
# 0     5.054983
# 1    19.068319
# ...

# %%
labelencoder = LabelEncoder()

# %%
data1.iloc[:,2] = labelencoder.fit_transform(data1.iloc[:,2])

# %%
data1.iloc[:,1] = labelencoder.fit_transform(data1.iloc[:,1])

# %%
data1.iloc[:,3] = labelencoder.fit_transform(data1.iloc[:,3])

# %%
data1.iloc[:,4] = labelencoder.fit_transform(data1.iloc[:,4])

# %%
data1.iloc[:,5] = labelencoder.fit_transform(data1.iloc[:,5])

# %%
data1.iloc[:,6] = labelencoder.fit_transform(data1.iloc[:,6])

# %%
data1.iloc[:,7] = labelencoder.fit_transform(data1.iloc[:,7])

# %%
data1.iloc[:,8] = labelencoder.fit_transform(data1.iloc[:,8])

# %%
data1.iloc[:,9] = labelencoder.fit_transform(data1.iloc[:,9])

# %%
data1.iloc[:,10] = labelencoder.fit_transform(data1.iloc[:,10])

# %%
data1.iloc[:,11] = labelencoder.fit_transform(data1.iloc[:,11])

# %%
data1.iloc[:,12] = labelencoder.fit_transform(data1.iloc[:,12])

# %%
data1.iloc[:,13] = labelencoder.fit_transform(data1.iloc[:,13])

# %%
data1.iloc[:,14] = labelencoder.fit_transform(data1.iloc[:,14])

# %%
data1.iloc[:,15] = labelencoder.fit_transform(data1.iloc[:,15])

# %%
data1.iloc[:,16] = labelencoder.fit_transform(data1.iloc[:,16])

# %%
data1.iloc[:,17] = labelencoder.fit_transform(data1.iloc[:,17])

# %%
data1.iloc[:,18] = labelencoder.fit_transform(data1.iloc[:,18])

# %%
data1.iloc[:,19] = labelencoder.fit_transform(data1.iloc[:,19])

# %%
data1.iloc[:,20] = labelencoder.fit_transform(data1.iloc[:,20])

# %%
data1.iloc[:,21] = labelencoder.fit_transform(data1.iloc[:,21])

# %%
data1.iloc[:,22] = labelencoder.fit_transform(data1.iloc[:,22])

# %%
data1.iloc[:,23] = labelencoder.fit_transform(data1.iloc[:,23])

# %%
data1.head(3)
# Out:
#    Unnamed: 0 cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0        1167       190           2         7       0    1               1
# 1        1037       750           0         6       0    1               3
# 2         309       281           1         5       1    4               1
#
#   gill_spacing gill_size gill_color  ... veil_type veil_color ring_number  \
# 0            2         0          7  ...         0          0           2
# 1            1         1          3  ...         1          0           2
# 2            1         0          8  ...         1          3           2
#
#   ring_type spore_print_color population habitat class stalk_height  \
# 0         6                 3          1       5     1    14.276173
# 1         6                 1          2       5     0     3.952715
# 2         6                 6          0       5     1     9.054265
#
#   cap_diameter
# 0     5.054983
# 1    19.068319
# 2     7.205884
#
# ...

# %% [markdown]
# ### **Task 4: SVM Implementation**

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
from sklearn.model_selection import train_test_split

# %%
data1.columns
# Out:
# Index(['Unnamed: 0', 'cap_shape', 'cap_surface', 'cap_color', 'bruises',
#        'odor', 'gill_attachment', 'gill_spacing', 'gill_size', 'gill_color',
#        'stalk_shape', 'stalk_root', 'stalk_surface_above_ring',
#        'stalk_surface_below_ring', 'stalk_color_above_ring',
#        'stalk_color_below_ring', 'veil_type', 'veil_color', 'ring_number',
#        'ring_type', 'spore_print_color', 'population', 'habitat', 'class',
#        'stalk_height', 'cap_diameter'],
#       dtype='object')

# %%
column_index = data1.columns.get_loc('population')
print(column_index)
# Out:
# 21

# %%
x =data1.iloc[:,:21]
y = data1['population']

# %%
y
# Out:
# 0       1
# 1       2
# 2       0
# 3       1
# 4       1
#        ..
# 1985    2
# 1988    2
# 1989    0
# 1996    2
# 1999    2
# Name: population, Length: 976, dtype: object

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
y_train
# Out:
# 457     5
# 359     3
# 332     2
# 571     0
# 51      5
#        ..
# 1423    3
# 209     4
# 905     5
# 749     3
# 997     5
# Name: population, Length: 732, dtype: object

# %%
le = LabelEncoder()

# %%
y_train = le.fit_transform(y_train)

# %%
df['population'].unique()
# Out:
# array(['clustered', 'numerous', 'abundant', 'scattered', 'several',
#        'solitary'], dtype=object)

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
ypred = svc.predict(x_test)

# %%
ypred
# Out:
# array([2, 3, 2, 0, 0, 0, 0, 3, 0, 0, 2, 0, 3, 0, 0, 0, 0, 4, 3, 0, 0, 0,
#        0, 3, 3, 0, 2, 0, 3, 3, 0, 4, 0, 0, 3, 0, 3, 3, 2, 2, 0, 3, 3, 2,
#        3, 4, 0, 2, 0, 4, 2, 0, 0, 0, 3, 2, 4, 0, 0, 2, 2, 2, 3, 0, 0, 0,
#        2, 3, 0, 0, 0, 2, 3, 2, 0, 0, 2, 0, 0, 0, 3, 0, 0, 3, 4, 3, 3, 3,
#        3, 3, 3, 0, 4, 0, 3, 3, 0, 0, 3, 0, 2, 0, 0, 0, 2, 3, 0, 4, 0, 0,
#        4, 0, 2, 0, 3, 2, 3, 4, 2, 0, 3, 3, 3, 3, 3, 3, 2, 0, 2, 0, 2, 0,
#        3, 0, 3, 3, 0, 0, 4, 2, 0, 3, 0, 4, 4, 4, 0, 0, 2, 0, 3, 0, 2, 4,
#        0, 0, 3, 2, 2, 0, 2, 3, 3, 0, 0, 0, 0, 0, 0, 3, 3, 0, 0, 2, 3, 0,
#        3, 3, 0, 2, 0, 3, 4, 0, 4, 0, 0, 0, 3, 0, 4, 0, 2, 0, 4, 0, 3, 0,
#        3, 0, 0, 0, 4, 2, 3, 3, 0, 2, 4, 0, 0, 0, 0, 0, 0, 0, 0, 2, 3, 3,
#        3, 0, 0, 2, 0, 0, 0, 0, 4, 3, 3, 3, 3, 0, 0, 0, 3, 2, 3, 0, 0, 0,
#        0, 3])

# %%
y_test = le.fit_transform(y_test)

# %%
print(svc.score(x_train,y_train),svc.score(x_test,y_test))
# Out:
# 0.21448087431693988 0.1598360655737705

# %% [markdown]
# ### **Hyperparameter Tuning**

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'C' : [0.1,0.001,1,2,3,4,5],
    'kernel' : ['linear','poly','rbf'],
      'gamma' : [0.1,0.001,1,2,5]}

# %%
grid = GridSearchCV(SVC(),param_grid=params,verbose=1)

# %%
grid.fit(x_train,y_train)

# %%
grid.best_params_

# %%
svc = SVC(C=0.1,gamma=0.1,kernel='poly')

# %%
svc.fit(x_train,y_train)
ypred = svc.predict(x_test)

# %%
print('Training Accuracy',svc.score(x_train,y_train))
print('Testing Accuracy',svc.score(x_test,y_test))
